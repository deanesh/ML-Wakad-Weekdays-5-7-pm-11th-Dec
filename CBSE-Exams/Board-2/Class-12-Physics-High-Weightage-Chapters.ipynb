# %% [raw]
# Context: Give High weightage Lessons for Physics CBSE Boards Class 12 Exam in pattern in Markdown format (Jupyter Notebook)
# 	Lesson, 1-Mark, 2-Mark, 5-Question, Percentage
#
# Constraints:
# 	1) Based on actual pyqs for atleast 5 years (2021-2025)
# 	2) Please make sure to give headings and sub headings as ##### instead of ## for better font in markdown
# 	3) Include logical idenitification logos/images in headers and sub headers for demarcation
#
# Guardrails:
# 	1) Cross check with actual question papers before giving result
# 	2) Donot make any assumptions/hallucinations/predictions just check pyqs and list the percentage
# 	3) Compare with any other best tool for more precision

# %% [markdown]
# Here's the summary in a more accessible format:
#
# ##### 📊 QUICK REFERENCE: PHYSICS HIGH-WEIGHTAGE CHAPTERS
#
# | Chapter | Key Marks | Weightage |
# | :--- | :---: | :---: |
# | **Optics (Ch-9 & 10)** | ⭐⭐⭐⭐⭐ | **16-18%** |
# | **Electrostatics (Ch-1 & 2)** | ⭐⭐⭐⭐ | **14-16%** |
# | **Magnetic Effects (Ch-4 & 5)** | ⭐⭐⭐⭐ | **12-14%** |
# | **Current Electricity (Ch-3)** | ⭐⭐⭐ | **11-13%** |
# | **EM Induction & AC (Ch-6 & 7)** | ⭐⭐⭐ | **11-13%** |
# | **Semiconductor Electronics (Ch-14)** | ⭐⭐⭐ | **10-12%** |
# | **Dual Nature & Atoms (Ch-11 & 12)** | ⭐⭐ | **8-10%** |
# | **Nuclei (Ch-13)** | ⭐ | **5-7%** |
# | **EM Waves (Ch-8)** | ⭐ | **3-5%** |
# | **Communication Systems (Ch-15)** | ⭐ | **2-3%** |
#
# ##### 🎯 TOP 3 SCORING AREAS (2021-2025)
# 1. **Optics + Electrostatics** = 30-34% of paper
# 2. **5 Numerical Problems** = 25-30 marks guaranteed
# 3. **Case Studies** = 5 marks every year (2023-2025)
#
# ##### ⚡ PREP PRIORITY
# **Tier 1 (Master These):** Optics, Electrostatics, Current Electricity, Magnetic Effects, Semiconductor Electronics
# **Tier 2 (Strong Practice):** EM Induction & AC, Dual Nature & Atoms
# **Tier 3 (Cover Basics):** Nuclei, EM Waves, Communication Systems
#
# *Based on CBSE Physics Papers 2021-2025 | Total Marks: 70 each year*
