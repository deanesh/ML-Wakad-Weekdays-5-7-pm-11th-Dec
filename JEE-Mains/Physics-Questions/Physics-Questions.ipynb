# %% [markdown]
# # JEE Mains Hard Physics Practice Set (10 Questions)
#
# **Topics:** Modern Physics, Mechanics, Electrodynamics, Optics, Thermodynamics, Waves, Electrostatics, Magnetism
#
# ---
#
# ## Q1 — Modern Physics
#
# A hydrogen-like atom in an excited state emits a photon of wavelength $121.5\ \mathrm{nm}$ when it transitions to the ground state.
#
# The same atom, in a different excited state, emits two photons: one of wavelength $102.5\ \mathrm{nm}$ and another of wavelength $656\ \mathrm{nm}$, ending in the first excited state.
#
# The atomic number $Z$ of the atom is:
#
# (A) 1
# (B) 2
# (C) 3
# (D) 4
#
# ---
#
# ## Q2 — Electrodynamics
#
# In the circuit shown, all capacitors are identical with capacitance
# $C = 2\ \mu\mathrm{F}$
# and all inductors are identical with inductance
# $L = 5\ \mathrm{mH}$.
#
# The AC source has voltage
# $V = V_0 \sin(\omega t)$
# with
# $\omega = 10^4\ \mathrm{rad\,s^{-1}}$.
#
# The equivalent impedance between points A and B of the **infinite LC ladder network** is:
#
# (A) $50\ \Omega$
# (B) $70.7\ \Omega$
# (C) $100\ \Omega$
# (D) $141.4\ \Omega$
#
# ---
#
# ## Q3 — Mechanics (Rotational Motion + WEP)
#
# A uniform solid cylinder of mass $m$ and radius $R$ rolls without slipping on a rough inclined plane of angle
# $\theta = 30^\circ$
# with the horizontal.
#
# At the bottom, it transitions smoothly to a **frictionless circular track** of radius $5R$.
#
# The minimum height $h$ from which the cylinder must be released so that it just completes the vertical circle on the track is:
#
# (A) $\dfrac{27}{4} R$
# (B) $\dfrac{15}{2} R$
# (C) $\dfrac{33}{4} R$
# (D) $9 R$
#
# ---
#
# ## Q4 — Optics (Newton’s Rings)
#
# A plano-convex lens of refractive index $1.5$ and radius of curvature
# $20\ \mathrm{cm}$
# is placed on a glass plate.
#
# Light of wavelength
# $600\ \mathrm{nm}$
# is incident normally, producing Newton’s rings.
#
# The lens is now raised vertically by
# $2\ \mu\mathrm{m}$
# without tilting.
#
# The approximate change in the diameter of the **10th bright ring** is:
#
# (A) $0.14\ \mathrm{mm}$
# (B) $0.28\ \mathrm{mm}$
# (C) $0.42\ \mathrm{mm}$
# (D) $0.56\ \mathrm{mm}$
#
# ---
#
# ## Q5 — Thermodynamics (V–T Diagram)
#
# One mole of an ideal monatomic gas undergoes a cyclic process
# $A \to B \to C \to A$.
#
# - Process $A \to B$ is **isochoric**
# - Process $B \to C$ is **linear in the $V$–$T$ plane**
# - Process $C \to A$ is **isothermal**
#
# Given:
# \[
# T_A = T_0,\quad T_B = 2T_0,\quad T_C = 4T_0
# \]
# \[
# V_A = V_0,\quad V_B = V_0,\quad V_C = 2V_0
# \]
#
# If the net work done by the gas in the cycle is $nRT_0$, the value of $n$ is:
#
# (A) $\ln 2 - 1.5$
# (B) $2\ln 2 - 1.5$
# (C) $\ln 2 - 0.5$
# (D) $2\ln 2 - 0.5$
#
# ---
#
# ## Q6 — Mechanics (Oscillations)
#
# A mass $m$ is attached to a spring of stiffness $k$ and rests on a smooth horizontal surface.
#
# Another identical mass $m$ is connected in parallel with a second spring of stiffness $k$, forming a **two-mass, two-spring system**.
#
# The **normal mode angular frequencies** of oscillation are:
#
# (A) $\sqrt{\dfrac{k}{m}},\ \sqrt{\dfrac{3k}{m}}$
# (B) $\sqrt{\dfrac{k}{2m}},\ \sqrt{\dfrac{2k}{m}}$
# (C) $\sqrt{\dfrac{2k}{m}},\ \sqrt{\dfrac{4k}{m}}$
# (D) $\sqrt{\dfrac{k}{m}},\ \sqrt{\dfrac{2k}{m}}$
#
# ---
#
# ## Q7 — Electrostatics
#
# Two identical conducting spheres of radius $R$ are placed a distance $d$ apart
# $(d \gg R)$
# and are charged with $+Q$ and $-Q$ respectively.
#
# The **force of attraction** between them is:
#
# (A) $\dfrac{1}{4\pi\varepsilon_0}\dfrac{Q^2}{d^2}$
# (B) $\dfrac{1}{4\pi\varepsilon_0}\dfrac{Q^2}{(d - 2R)^2}$
# (C) $\dfrac{1}{4\pi\varepsilon_0}\dfrac{Q^2}{(d + 2R)^2}$
# (D) $\dfrac{1}{4\pi\varepsilon_0}\dfrac{Q^2}{d^2}\!\left(1 - \dfrac{R^2}{d^2}\right)$
#
# ---
#
# ## Q8 — Magnetism (Electromagnetic Induction)
#
# A square loop of side $a$ lies in a **time-varying magnetic field**
# \[
# B(t) = B_0 \cos(\omega t)
# \]
# perpendicular to the plane of the loop.
#
# The **maximum induced emf** in the loop is:
#
# (A) $a^2 B_0 \omega$
# (B) $a^2 B_0 \omega \sin(\omega t)$
# (C) $a^2 B_0 \omega \cos(\omega t)$
# (D) $2a^2 B_0 \omega$
#
# ---
#
# ## Q9 — Waves (Standing Waves)
#
# A string of length $L$ and linear mass density $\mu$ is fixed at both ends.
#
# A standing wave with **three antinodes** is formed.
#
# The fundamental frequency $f_1$ is related to the wave speed $v$ as:
#
# (A) $f_1 = \dfrac{v}{2L}$
# (B) $f_1 = \dfrac{v}{L}$
# (C) $f_1 = \dfrac{v}{3L}$
# (D) $f_1 = \dfrac{3v}{2L}$
#
# ---
#
# ## Q10 — Modern Physics (Photoelectric Effect)
#
# A metallic surface is irradiated with light of wavelength
# $400\ \mathrm{nm}$,
# producing photoelectrons with maximum kinetic energy
# $2\ \mathrm{eV}$.
#
# If the wavelength of incident light is changed to
# $300\ \mathrm{nm}$,
#
# the **maximum kinetic energy** of the photoelectrons is:
#
# (A) $3.1\ \mathrm{eV}$
# (B) $4.1\ \mathrm{eV}$
# (C) $4.5\ \mathrm{eV}$
# (D) $5.1\ \mathrm{eV}$
#
# ---
