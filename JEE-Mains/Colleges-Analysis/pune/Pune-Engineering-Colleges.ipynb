# %% [markdown]
# ##### `Pune Engineering Colleges`

# %% [markdown]
# `List Top 20 Engineering colleges in Pune in csv format`
#
#     Name, Location, Established_Year, HomePage_URL, DTE_Code
#     Guard rails:
#         If any col data is not available fill with empty string or number as applicable

# %% [markdown]
# Come up with Departments/Branches per College and provide link for proof
#
#     Name, Branch
#     Guard rails:
#             Make sure details are properly gather rather than in hurry. If not sure leave blank

# %%
# Step-1: Data Ingestion
import pandas as pd
df = pd.read_csv('pune-engg-colleges.csv')
df.head(3)
# Out:
#                                            Name           Location  \
# 0                 COEP Technological University  Shivajinagar Pune
# 1  Pune Institute of Computer Technology (PICT)    Dhankawadi Pune
# 2     Vishwakarma Institute of Technology (VIT)     Bibwewadi Pune
#
#    Established_Year                 HomePage_URL  DTE_Code
# 0              1854  https://www.coeptech.ac.in/      6006
# 1              1983         http://www.pict.edu/      6271
# 2              1983         https://www.vit.edu/      6273
