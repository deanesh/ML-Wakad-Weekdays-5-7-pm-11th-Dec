# %% [markdown]
# ---
#
# ##### JEE Mains Practice Set: Mathematics
#
# ---
#
# ##### Section A: Coordinate Geometry (Conics)
#
# ##### Q1.
#
# The locus of the point of intersection of tangents to the parabola
#
# $$
# y^2 = 4ax
# $$
#
# which meet at an angle of $45^\circ$ is:
#
# (a)
# $$
# (x + a)^2 = 4(y^2 - 4ax)
# $$
#
# (b)
# $$
# (x + a)^2 = 2(y^2 - 4ax)
# $$
#
# (c)
# $$
# (x + a)^2 = (y^2 - 4ax)
# $$
#
# (d)
# $$
# (x + a)^2 = 8(y^2 - 4ax)
# $$
#
# **Justification:** Requires combining the pair of tangents equation, angle condition between tangents, and elimination of parameters.
#
# ---
#
# ##### Q2.
#
# From a point $P$ on the ellipse
#
# $$
# \frac{x^2}{25} + \frac{y^2}{16} = 1
# $$
#
# tangents are drawn to the hyperbola
#
# $$
# \frac{x^2}{25} - \frac{y^2}{16} = 1
# $$
#
# If the chord of contact touches the ellipse
#
# $$
# \frac{x^2}{a^2} + \frac{y^2}{b^2} = 1
# $$
#
# where
#
# $$
# a^2 = \frac{m}{n} \quad (m,n \text{ coprime})
# $$
#
# then $m+n$ equals:
#
# (a) 29
# (b) 41
# (c) 53
# (d) 61
#
# **Justification:** Involves chord of contact, condition of tangency to a second ellipse, and rational parameterization.
#
# ---
#
# ##### Q3.
#
# A variable chord of the hyperbola
#
# $$
# \frac{x^2}{a^2} - \frac{y^2}{b^2} = 1
# $$
#
# subtends a right angle at the origin. The locus of the foot of the perpendicular from the origin to this chord is:
#
# (a)
# $$
# (x^2 + y^2)^2 = a^2x^2 - b^2y^2
# $$
#
# (b)
# $$
# (x^2 + y^2)^2 = a^2x^2 + b^2y^2
# $$
#
# (c)
# $$
# (x^2 + y^2)^2 = b^2x^2 - a^2y^2
# $$
#
# (d)
# $$
# (x^2 + y^2)^2 = a^2b^2(x^2 - y^2)
# $$
#
# **Justification:** Uses right-angle chord condition, foot of perpendicular locus, and homogeneous equation techniques.
#
# ---
#
# ##### Q4.
#
# The tangent at any point $P$ on the hyperbola
#
# $$
# \frac{x^2}{a^2} - \frac{y^2}{b^2} = 1
# $$
#
# meets the asymptotes at $Q$ and $R$. If the circle circumscribing triangle $OQR$ (where $O$ is the origin) meets the hyperbola at four points, then the **product of the eccentric angles** of these four points is:
#
# (a) $\pi^2$
# (b) $2\pi^2$
# (c) $4\pi^2$
# (d) $8\pi^2$
#
# **Justification:** Combines hyperbola geometry, asymptotes, circle through three points, and parametric intersection.
#
# ---
#
# ##### Q5.
#
# Two parabolas
#
# $$
# y^2 = 4a(x - k_1), \quad x^2 = 4a(y - k_2)
# $$
#
# always touch each other. The locus of their point of contact is:
#
# (a) $xy = 2a^2$
# (b) $xy = a^2$
# (c) $xy = 4a^2$
# (d) $xy = 8a^2$
#
# **Justification:** Uses condition of tangency (equal values and equal derivatives).
#
# ---
#
# ##### Section B: Integral Calculus
#
# ##### Q6.
#
# Evaluate:
#
# $$
# \int_0^{\pi} \frac{x \sin^8 x}{\sin^8 x + \cos^8 x} , dx
# $$
#
# (a) $\frac{\pi}{4}$
# (b) $\frac{\pi}{2}$
# (c) $\frac{\pi}{8}$
# (d) $\frac{\pi}{16}$
#
# **Justification:** Uses King’s property and symmetry.
#
# ---
#
# ##### Q7.
#
# If
#
# $$
# I_n = \int_0^{\pi/4} \tan^n x , dx
# $$
#
# then:
#
# $$
# \lim_{n \to \infty} n[I_n + I_{n+2}]
# $$
#
# equals:
#
# (a) 0
# (b) 1
# (c) $\frac{1}{2}$
# (d) $\infty$
#
# ---
#
# ##### Q8.
#
# Evaluate:
#
# $$
# \int \frac{x^4 + 1}{x^6 + 1} , dx
# $$
#
# (a) $\tan^{-1} x + \frac{1}{3}\tan^{-1} x^3 + C$
# (b) $\tan^{-1} x - \frac{1}{3}\tan^{-1} x^3 + C$
# (c) $\tan^{-1} x + \frac{1}{2}\tan^{-1} x^2 + C$
# (d) $\tan^{-1} x - \frac{1}{2}\tan^{-1} x^2 + C$
#
# ---
#
# ##### Q9.
#
# Let
#
# $$
# f(x) = \int \frac{x^2}{(x \sin x + \cos x)^2} , dx
# $$
#
# Then $f(x) + f'(x)\tan x$ equals:
#
# (a) $\frac{\sin x}{x \sin x + \cos x} + C$
# (b) $\frac{\cos x}{x \sin x + \cos x} + C$
# (c) $\frac{x \cos x}{x \sin x + \cos x} + C$
# (d) $\frac{x \sin x}{x \sin x + \cos x} + C$
#
# ---
#
# ##### Q10.
#
# Evaluate:
#
# $$
# \int_0^1 \frac{\tan^{-1}(1 - x + x^2)}{1 + x^2} , dx
# $$
#
# (a) $\frac{\pi}{2}\ln 2$
# (b) $\pi \ln 2$
# (c) $\frac{\pi}{4}\ln 2$
# (d) $2\pi \ln 2$
#
# ---
#
# ##### Section C: Algebra (Complex Numbers & Quadratics)
#
# ##### Q11.
#
# If $|z_1| = |z_2| = |z_3| = 1$ and
#
# $$
# z_1 + z_2 + z_3 = 0
# $$
#
# then the circumradius of the triangle formed is:
#
# (a) $\frac{1}{2}$
# (b) $\frac{1}{3}$
# (c) $1$
# (d) $\frac{2}{3}$
#
# ---
#
# ##### Q12.
#
# If $\alpha, \beta$ are roots of
#
# $$
# x^2 - 2x + 4 = 0
# $$
#
# then $\alpha^n + \beta^n$ is **not real** for:
#
# (a) $n = 6$
# (b) $n = 8$
# (c) $n = 10$
# (d) $n = 12$
#
# ---
#
# ##### Q13.
#
# Number of real values of $k$ such that
#
# $$
# x^2 + (2+k)x + 2k = 0
# $$
#
# has **both roots integers**:
#
# (a) 0
# (b) 1
# (c) 2
# (d) Infinite
#
# ---
#
# ##### Q14.
#
# If
#
# $$
# z = \frac{1 + i\sqrt{3}}{1 - i}
# $$
#
# then the polar form of $z^{2023}$ is:
#
# (a) $2^{1011}\left(\cos \frac{5\pi}{12} + i\sin \frac{5\pi}{12}\right)$
# (b) $2^{1011}\left(\cos \frac{7\pi}{12} + i\sin \frac{7\pi}{12}\right)$
# (c) $2^{1011}\left(\cos \frac{11\pi}{12} + i\sin \frac{11\pi}{12}\right)$
# (d) $2^{1011}\left(\cos \frac{13\pi}{12} + i\sin \frac{13\pi}{12}\right)$
#
# ---
#
# ##### Q15.
#
# If
#
# $$
# |z^2 - 1| = |z|^2 + 1
# $$
#
# then $z$ lies on:
#
# (a) a circle
# (b) a straight line
# (c) a parabola
# (d) an ellipse
#
# ---
#
#
# ##### Section D: Vector & 3D Geometry
#
# ---
#
# ##### Q16.
#
# Let
#
# $$
# \vec{a} = \hat{i} + \hat{j} + \hat{k}, \quad
# \vec{b} = \hat{i} - \hat{j} + \hat{k}, \quad
# \vec{c} = \hat{i} + \hat{j} - \hat{k}
# $$
#
# A vector in the plane of $\vec{a}$ and $\vec{b}$ whose projection on $\vec{c}$ has magnitude
#
# $$
# \sqrt{\frac{2}{3}}
# $$
#
# is:
#
# (a) $2\hat{i} + 3\hat{j} - 3\hat{k}$
# (b) $2\hat{i} + 3\hat{j} + 3\hat{k}$
# (c) $-2\hat{i} - \hat{j} + 5\hat{k}$
# (d) $2\hat{i} + \hat{j} + \hat{k}$
#
# **Justification:** Requires finding a vector in the plane of $\vec{a}, \vec{b}$ and applying the projection formula.
#
# ---
#
# ##### Q17.
#
# The angle between the lines
#
# $$
# \frac{x-2}{3} = \frac{y+1}{-2} = \frac{z-2}{0}
# $$
#
# and
#
# $$
# \frac{x-1}{1} = \frac{2y+3}{3} = \frac{z+5}{2}
# $$
#
# is:
#
# (a) $\cos^{-1}\left(\frac{3}{\sqrt{130}}\right)$
# (b) $\cos^{-1}\left(\frac{1}{\sqrt{130}}\right)$
# (c) $\cos^{-1}\left(\frac{5}{\sqrt{130}}\right)$
# (d) $\cos^{-1}\left(\frac{7}{\sqrt{130}}\right)$
#
# **Justification:** Convert to direction ratios and apply dot-product formula.
#
# ---
#
# ##### Q18.
#
# A line with direction ratios $2,1,2$ meets the lines
#
# $$
# \frac{x-1}{2} = \frac{y-2}{1} = \frac{z-3}{1}
# $$
#
# and
#
# $$
# \frac{x+2}{3} = \frac{y-1}{2} = \frac{z+1}{1}
# $$
#
# at points $A$ and $B$ respectively. Then the length $AB$ is:
#
# (a) 3
# (b) 4
# (c) 5
# (d) 6
#
# **Justification:** Use parametric forms and direction ratios to find $A,B$.
#
# ---
#
# ##### Q19.
#
# The distance of the point $(1,1,1)$ from the plane passing through
#
# $$
# (1,0,0), \ (0,1,0), \ (0,0,1)
# $$
#
# measured parallel to the line
#
# $$
# \frac{x}{2} = \frac{y}{3} = \frac{z}{6}
# $$
#
# is:
#
# (a) $\frac{1}{\sqrt{6}}$
# (b) $\frac{2}{\sqrt{6}}$
# (c) $\frac{3}{\sqrt{6}}$
# (d) $\frac{4}{\sqrt{6}}$
#
# **Justification:** Draw a line through $(1,1,1)$ parallel to the given line and find its intersection with the plane.
#
# ---
#
# ##### Q20.
#
# Let $\vec{a}, \vec{b}, \vec{c}$ be unit vectors such that
#
# $$
# \vec{a} + \vec{b} + \vec{c} = \vec{0}
# $$
#
# Which of the following is true?
#
# (a) $\vec{a}\times\vec{b} = \vec{b}\times\vec{c} = \vec{c}\times\vec{a}$
# (b) $\vec{a}\times\vec{b} = \vec{b}\times\vec{c} = \vec{c}\times\vec{a} \neq \vec{0}$
# (c) $\vec{a}\times\vec{b}, \vec{b}\times\vec{c}, \vec{c}\times\vec{a}$ are mutually perpendicular
# (d) $\vec{a}\times\vec{b} = \vec{b}\times\vec{c} = \vec{c}\times\vec{a} = \vec{0}$
#
# **Justification:** Cross product of $\vec{a}+\vec{b}+\vec{c}=\vec{0}$ with each vector gives equality of cross products.
#
# ---
#
# ##### Additional Hard Questions (21–30)
#
# ---
#
# ##### Q21.
#
# The area bounded by the parabola
#
# $$
# y^2 = 4ax
# $$
#
# and its latus rectum in the first quadrant is rotated about the $x$-axis. The volume generated is:
#
# (a) $\frac{8\pi a^3}{3}$
# (b) $\frac{16\pi a^3}{3}$
# (c) $\frac{32\pi a^3}{3}$
# (d) $\frac{64\pi a^3}{3}$
#
# ---
#
# ##### Q22.
#
# If
#
# $$
# \int_0^{\pi/2} \ln(\sin x),dx = -\frac{\pi}{2}\ln 2
# $$
#
# then
#
# $$
# \int_0^{\pi} x\ln(\sin x),dx
# $$
#
# equals:
#
# (a) $-\frac{\pi^2}{2}\ln 2$
# (b) $-\pi^2\ln 2$
# (c) $-\frac{3\pi^2}{4}\ln 2$
# (d) $-\frac{\pi^2}{4}\ln 2$
#
# ---
#
# ##### Q23.
#
# If
#
# $$
# z^7 = 1,\quad z \neq 1
# $$
#
# then
#
# $$
# \left|\sum_{k=1}^{6}\frac{1}{1+z^k}\right|
# $$
#
# equals:
#
# (a) 1
# (b) 2
# (c) 3
# (d) 4
#
# ---
#
# ##### Q24.
#
# The number of distinct real roots of
#
# $$
# \begin{vmatrix}
# x & 1 & 1 \
# 1 & x & 1 \
# 1 & 1 & x
# \end{vmatrix} = 0
# $$
#
# is:
#
# (a) 0
# (b) 1
# (c) 2
# (d) 3
#
# ---
#
# ##### Q25.
#
# The shortest distance between the lines
#
# $$
# \frac{x-3}{1} = \frac{y-5}{-2} = \frac{z-7}{1}
# $$
#
# and
#
# $$
# \frac{x+1}{7} = \frac{y+1}{-6} = \frac{z+1}{1}
# $$
#
# is:
#
# (a) $2\sqrt{29}$
# (b) $3\sqrt{29}$
# (c) $4\sqrt{29}$
# (d) $5\sqrt{29}$
#
# ---
#
# ##### Q26.
#
# If $\alpha,\beta$ are roots of
#
# $$
# ax^2 + bx + c = 0
# $$
#
# and $\alpha+h,\beta+h$ are roots of
#
# $$
# px^2 + qx + r = 0
# $$
#
# then
#
# $$
# \frac{b^2 - 4ac}{q^2 - 4pr}
# $$
#
# equals:
#
# (a) $\frac{a^2}{p^2}$
# (b) $\frac{a}{p}$
# (c) $\frac{p^2}{a^2}$
# (d) $1$
#
# ---
#
# ##### Q27.
#
# Evaluate:
#
# $$
# \int_{-2}^{2} \min\left(|x|,\sqrt{2-x^2}\right),dx
# $$
#
# (a) $\pi$
# (b) $\frac{\pi}{2}$
# (c) $\frac{\pi}{4}$
# (d) $\frac{\pi}{8}$
#
# ---
#
# ##### Q28.
#
# If the system
#
# $$
# x+ay+a^2z=0,\quad
# x+by+b^2z=0,\quad
# x+cy+c^2z=0
# $$
#
# has a non-trivial solution, then:
#
# (a) $\frac{1}{a}+\frac{1}{b}+\frac{1}{c}=0$
# (b) $a+b+c=0$
# (c) $ab+bc+ca=0$
# (d) $abc=1$
#
# ---
#
# ##### Q29.
#
# The locus of the midpoint of chords of the circle
#
# $$
# x^2 + y^2 = 16
# $$
#
# which subtend a right angle at the origin is:
#
# (a) $x^2 + y^2 = 4$
# (b) $x^2 + y^2 = 8$
# (c) $x^2 + y^2 = 12$
# (d) $x^2 + y^2 = 16$
#
# ---
#
# ##### Q30.
#
# The number of values of $\theta \in [0,2\pi]$ for which the vectors
#
# $$
# (1,\sin\theta,1),\quad (1,\cos\theta,1),\quad (1,\tan\theta,1)
# $$
#
# are coplanar is:
#
# (a) 2
# (b) 4
# (c) 6
# (d) 8
#
# ---
