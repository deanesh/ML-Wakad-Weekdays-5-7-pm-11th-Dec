# %% [markdown]
# # JEE Mains Hard Chemistry Practice Set (10 Questions)
#
# **Topics:** Organic Chemistry, Physical Chemistry, Inorganic Chemistry, Coordination Compounds, p-Block
#
# ---
#
# ## Q1 — Organic Chemistry (GOC + Hydrocarbons)
#
# Compound $\mathbf{A}$ $(\mathrm{C_9H_{10}O})$ does **not** give Tollen's test but on treatment with $\mathrm{LiAlH_4}$ followed by acidification gives $\mathbf{B}$ $(\mathrm{C_9H_{12}O})$.
#
# $\mathbf{B}$ on heating with concentrated $\mathrm{H_2SO_4}$ gives $\mathbf{C}$ $(\mathrm{C_9H_{10}})$.
#
# $\mathbf{C}$ on ozonolysis gives only benzaldehyde.
#
# $\mathbf{C}$ on treatment with $\mathrm{Br_2}$ in $\mathrm{CCl_4}$ gives a racemic mixture.
#
# The number of stereoisomers possible for $\mathbf{B}$ is:
#
# (A) 2
# (B) 4
# (C) 6
# (D) 8
#
# ---
#
# ## Q2 — Physical Chemistry (Chemical Kinetics)
#
# For the reaction sequence:
#
# $$
# A \xrightarrow{k_1} B \xrightarrow{k_2} C
# $$
#
# with
# $k_1 = 1 \times 10^{-3}\ \mathrm{s^{-1}}$,
# $k_2 = 2 \times 10^{-3}\ \mathrm{s^{-1}}$,
#
# the initial concentration of $A$ is $0.1\ \mathrm{M}$ and $[B]_0 = [C]_0 = 0$.
#
# The time (in seconds) at which the concentration of $B$ is maximum is:
#
# (A) $200 \ln 2$
# (B) $500 \ln 2$
# (C) $1000 \ln 2$
# (D) $2000 \ln 2$
#
# ---
#
# ## Q3 — Chemical Bonding
#
# Among the following species:
#
# 1. $[\mathrm{Ni(CN)_4}]^{2-}$
# 2. $[\mathrm{NiCl_4}]^{2-}$
# 3. $[\mathrm{MnCl_4}]^{2-}$
# 4. $[\mathrm{Fe(CN)_6}]^{4-}$
#
# The total number of species that are **diamagnetic** and have **tetrahedral geometry** is:
#
# (A) 0
# (B) 1
# (C) 2
# (D) 3
#
# ---
#
# ## Q4 — Coordination Compounds
#
# In an octahedral complex $[\mathrm{Co(NH_3)_4Cl_2}]^{+}$, two chlorine atoms are arranged **trans** to each other.
#
# This complex is treated with excess $\mathrm{AgNO_3}$ to give **1 mole of AgCl precipitate per mole of complex**.
#
# The number of geometrical isomers possible for the original complex $[\mathrm{Co(NH_3)_4Cl_2}]^{+}$ that fit the above data is:
#
# (A) 1
# (B) 2
# (C) 3
# (D) 4
#
# ---
#
# ## Q5 — p-Block Elements
#
# When compound $\mathbf{P}$ (a white solid) is heated, it gives a colourless gas $\mathbf{Q}$ which turns lime water milky.
#
# The residue left after heating $\mathbf{P}$ dissolves in water to give an alkaline solution $\mathbf{R}$.
#
# When excess $\mathrm{CO_2}$ is passed through $\mathbf{R}$, it forms a compound $\mathbf{S}$.
#
# Heating $\mathbf{S}$ gives back $\mathbf{Q}$.
#
# $\mathbf{P}$ is:
#
# (A) $\mathrm{CaCO_3}$
# (B) $\mathrm{NaHCO_3}$
# (C) $\mathrm{Ca(HCO_3)_2}$
# (D) $\mathrm{CaC_2O_4}$
#
# ---
#
# ## Q6 — Organic Chemistry (Aromatic Compounds)
#
# Compound $\mathbf{X}$ $(\mathrm{C_7H_6O})$ reacts with 2,4-DNP reagent and gives a yellow precipitate.
#
# When $\mathbf{X}$ is treated with $\mathrm{NaOH}$ followed by $\mathrm{CO_2}$ (Kolbe–Schmitt reaction), a phenolic product is obtained.
#
# The structure of $\mathbf{X}$ is:
#
# (A) Benzaldehyde
# (B) Phenol
# (C) Acetophenone
# (D) Benzoic acid
#
# ---
#
# ## Q7 — Physical Chemistry (Electrochemistry)
#
# A galvanic cell is constructed using $\mathrm{Zn/Zn^{2+}}$ and $\mathrm{Cu/Cu^{2+}}$ electrodes at $298\ \mathrm{K}$.
#
# The standard cell potential is $1.10\ \mathrm{V}$.
#
# If 1 mole of electrons is transferred, the standard free energy change $\Delta G^\circ$ is:
#
# (A) $-1.10 \times 10^5\ \mathrm{J}$
# (B) $-2.20 \times 10^5\ \mathrm{J}$
# (C) $1.10 \times 10^5\ \mathrm{J}$
# (D) $2.20 \times 10^5\ \mathrm{J}$
#
# ---
#
# ## Q8 — Inorganic Chemistry (Transition Metals)
#
# Which of the following complexes is **low-spin and diamagnetic**?
#
# (A) $[\mathrm{Fe(H_2O)_6}]^{2+}$
# (B) $[\mathrm{Fe(CN)_6}]^{4-}$
# (C) $[\mathrm{CoF_6}]^{3-}$
# (D) $[\mathrm{NiCl_4}]^{2-}$
#
# ---
#
# ## Q9 — Physical Chemistry (Thermodynamics)
#
# For an ideal gas undergoing adiabatic expansion, the work done is:
#
# $$
# W = \frac{P_1 V_1 - P_2 V_2}{\gamma - 1}
# $$
#
# If
# $P_2 V_2 = \dfrac{1}{2} P_1 V_1$
# and $\gamma = 1.4$,
#
# the work done $W$ is:
#
# (A) $0.5 P_1 V_1$
# (B) $0.714 P_1 V_1$
# (C) $1.0 P_1 V_1$
# (D) $1.4 P_1 V_1$
#
# ---
#
# ## Q10 — Organic Chemistry (Stereochemistry)
#
# Compound $\mathbf{Y}$ is **2-bromo-3-methylpentane**.
#
# The total number of **optical isomers** possible for $\mathbf{Y}$ is:
#
# (A) 2
# (B) 4
# (C) 6
# (D) 8
#
# ---
