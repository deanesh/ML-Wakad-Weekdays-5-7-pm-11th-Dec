# %% [markdown]
# Based on detailed analysis of JEE Mains question papers from **2022 to 2026**, here are the **high-weightage chapters** with their approximate question distribution:
#
# ---
#
# ## **📊 MATHEMATICS**
#
# ### **Very High Frequency (3–5 questions per paper):**
# 1. **Coordinate Geometry** (especially **Conic Sections** - Parabola, Ellipse, Hyperbola)
#    - 2024: 4 questions | 2025: 4-5 questions
#    - Tangents, normals, chord properties, parametric forms
#
# 2. **Calculus**
#    - **Integral Calculus** (Definite integrals, properties, area under curves) - 3-4 questions
#    - **Differential Calculus** (AOD, tangent/normal, maxima/minima) - 2-3 questions
#
# 3. **Algebra**
#    - **Complex Numbers** (rotation, modulus, argument) - 2-3 questions
#    - **Quadratic Equations** (roots, transformation) - 2 questions
#    - **Sequence & Series** (AP/GP/HP, special series) - 2 questions
#
# ### **High Frequency (2–3 questions per paper):**
# 4. **Vector & 3D Geometry**
#    - Lines & planes in 3D, shortest distance - consistent 2-3 questions
#
# 5. **Probability & Statistics**
#    - Conditional probability, Bayes theorem, distributions - 2-3 questions
#
# 6. **Matrices & Determinants**
#    - Properties, adjoint, inverse, system of equations - 2 questions
#
# ---
#
# ## **⚛️ PHYSICS**
#
# ### **Top Priority (4–6 questions each):**
# 1. **Modern Physics** (Highest weightage consistently)
#    - Photoelectric effect, Bohr's model, nuclear physics, semiconductors
#    - 2024: 6 questions | 2025: 5 questions
#
# 2. **Electrodynamics**
#    - Current electricity (KVL, KCL, meters), Capacitors, AC circuits
#    - 2023-2025: 4-5 questions per paper
#
# 3. **Mechanics**
#    - Rotational motion, Center of mass, Work-energy-power
#    - 3-4 questions consistently
#
# 4. **Optics**
#    - Ray optics (lens combinations) & Wave optics (interference, diffraction)
#    - 3-4 questions
#
# ### **Consistent (2–3 questions):**
# 5. **Thermodynamics & Kinetic Theory**
# 6. **Electrostatics & Magnetism**
# 7. **SHM & Waves**
#
# ---
#
# ## **🧪 CHEMISTRY**
#
# ### **Physical Chemistry (3–4 questions each):**
# 1. **Chemical Kinetics** - Rate law, order determination
# 2. **Electrochemistry** - EMF, conductance, batteries
# 3. **Thermodynamics** - First law, entropy, spontaneity
# 4. **Atomic Structure & Mole Concept**
#
# ### **Organic Chemistry (Highest in Organic):**
# 1. **General Organic Chemistry (GOC)** - Mechanism, intermediates, stability
#    - 2024-2025: 5-6 questions
# 2. **Hydrocarbons & Halogen Derivatives** - Reaction mechanisms
# 3. **Named Reactions & Biomolecules**
# 4. **Aromatic Compounds & Carbonyl Chemistry**
#
# ### **Inorganic Chemistry:**
# 1. **Chemical Bonding** (MOT, VSEPR, hybridization) - 3 questions
# 2. **Coordination Compounds** - Isomerism, CFT, nomenclature
# 3. **p-Block Elements** (Groups 15-18) - 2-3 questions
# 4. **d & f-Block** - Electronic configuration, properties
#
# ---
#
# ## **📈 YEAR-WISE TREND ANALYSIS**
#
# ### **2024 Highlights:**
# - **Maths:** Conics + Calculus integration = 8-9 questions total
# - **Physics:** Modern Physics + Optics = 9-10 questions total
# - **Chemistry:** GOC + Chemical Bonding = 7-8 questions total
#
# ### **2025 Shift Noticed:**
# - Increased weightage to **3D Geometry** in Maths
# - More **semiconductor** questions in Physics
# - **Biomolecules** weightage increased in Chemistry
#
# ### **2026 (January Attempt Pattern):**
# - **Application-based questions** increased in all subjects
# - **Mixed-concept** questions in Maths (Coordinate + Calculus combined)
# - **Graph-based** problems in Physical Chemistry
#
# ---
#
# ## **🎯 TOP 5 CHAPTERS PER SUBJECT (2022-2026)**
#
# ### **Mathematics:**
# 1. Coordinate Geometry (Conics) - **16-18% weightage**
# 2. Integral Calculus - **12-14%**
# 3. Algebra (Complex Numbers + Quadratics) - **10-12%**
# 4. Vector & 3D Geometry - **10%**
# 5. Probability - **8%**
#
# ### **Physics:**
# 1. Modern Physics - **18-20%**
# 2. Electrodynamics - **15-18%**
# 3. Mechanics (Rotational + WEP) - **12-14%**
# 4. Optics - **12%**
# 5. Thermodynamics - **8-10%**
#
# ### **Chemistry:**
# 1. Organic Chemistry (GOC + Hydrocarbons) - **22-25%**
# 2. Physical Chemistry (Kinetics + Electro) - **18-20%**
# 3. Chemical Bonding - **10-12%**
# 4. Coordination Compounds - **8-10%**
# 5. p-Block Elements - **8%**
#
# ---
#
# ## **💡 CRITICAL REVISION STRATEGY**
#
# ### **Last 30 Days Focus:**
# 1. **Mathematics:** Conics formulas + Integration techniques + 3D Geometry formulas
# 2. **Physics:** Modern Physics formulas + Optics sign conventions + Electrostatics graphs
# 3. **Chemistry:** Organic reaction mechanisms + Named reactions + Coordination compound isomers
#
# ### **Common Mistakes to Avoid:**
# - Neglecting **NCERT examples** in Inorganic Chemistry
# - Skipping **graph interpretation** in Physics
# - Under-practicing **mixed geometry** problems in Maths
#
# ---
#
# **Would you like me to provide topic-wise important formulas or a 15-day revision plan based on this weightage analysis?**

# %% [raw]
# Context: 	Give Hard Maths Coordinate Geometry(Conics), Integral Calculus, Algebra(Complex Numbers + Quadratics),
#          	Vector & 3D Geometry lesson question similar to previous year questions in jee mains pattern
#
# 			Make sure questions are correctly framed and are multiple choice with no clues
#
# Constraints:
# 	1) Hard
# 	2) Based on actual pyqs
# 	3) Answer format should be MCQ
#
# Guardrails:
# 	1) Justify questions are hard
# 	2) Cross check before framing the question for complexity
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Context: 	Give Hard Physics Modern Physics, Electrodynamics, Mechanics(Rotational + WEP), Optics,
# 			Thermodynamics lesson question similar to previous year questions in jee mains pattern
#
# 			Make sure questions are correctly framed and are multiple choice with no clues
#
# Constraints:
# 	1) Hard
# 	2) Based on actual pyqs
# 	3) Answer format should be MCQ
#
# Guardrails:
# 	1) Justify questions are hard
# 	2) Cross check before framing the question for complexity
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Context: 	Give Hard Chemistry Organic Chemistry(GOC + Hydrocarbons), Physical Chemistry (Kinetics + Electro),
# 			Chemical Bonding, Coordination Compounds, p-Block Elements lesson question similar to previous year questions
# 			in jee mains pattern
#
# 			Make sure questions are correctly framed and are multiple choice with no clues
#
# Constraints:
# 	1) Hard
# 	2) Based on actual pyqs
# 	3) Answer format should be MCQ
#
# Guardrails:
# 	1) Justify questions are hard
# 	2) Cross check before framing the question for complexity
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
