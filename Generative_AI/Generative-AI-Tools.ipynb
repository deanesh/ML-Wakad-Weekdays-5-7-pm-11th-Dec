# %% [markdown]
# ##### <b>Appplication related - Gemini Google AI<b>
# ###### Link: https://gemini.google.com
# ##### <b>General Task related - ChatGPT</b>
# ###### Link: https://chatgpt.com
# ##### <b>Code related - Claude AI<b>
# ###### Link: https://claude.ai/
# ##### <b>Deep Problem Analysis - Deepseek<b>
# ###### Link: https://chat.deepseek.com/sign_in
# ##### <b>Twitter AI - grok<b>
# ###### Link: https://grok.com/
# ##### <b>Opensource AI - groq<b>
# ###### Link: https://groq.com/
