# %% [markdown]
# 1. Appplication related - Gemini Google AI( https://gemini.google.com )
# 2. General Task related - ChatGPT( https://chatgpt.com )
# 3. Code related - Claude AI( https://claude.ai/ )
# 4. Deep Problem Analysis - Deepseek( https://chat.deepseek.com/sign_in )
# 5. Twitter AI - grok( https://grok.com/ )
# 6. Opensource AI - groq( https://groq.com/ )
#
# GPT: Generative Pre-Trained Transformer
# | Technique                    | What it Does (Short)                        | One Example                    |
# | ---------------------------- | ------------------------------------------- | ------------------------------ |
# | Transformers                 | Uses self-attention to understand context   | GPT generates coherent text    |
# | Large Language Models (LLMs) | Predict next token to generate text         | ChatGPT answers questions      |
# | GANs                         | Generator vs Discriminator to create data   | StyleGAN creates face images   |
# | Diffusion Models             | Removes noise step-by-step to generate data | Stable Diffusion text-to-image |
# | VAEs                         | Learns latent space for smooth generation   | MNIST digit generation         |
# | Autoregressive Models        | Generates output sequentially               | GPT predicts next word         |
# | Prompt Engineering           | Guides model behavior via prompts           | Few-shot prompting             |
# | Fine-Tuning / LoRA           | Adapts pre-trained models                   | Legal document LLM             |
# | RLHF                         | Aligns output using human feedback          | Chatbot response improvement   |
# | Multimodal Models            | Works across multiple data types            | DALL·E text-to-image           |
