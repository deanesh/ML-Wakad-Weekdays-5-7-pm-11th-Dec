# %% [markdown]
# #### `BERT (Bidirectional Encoder Representations from Transformers)`
# BERT is a transformer-based model that reads text bidirectionally, understanding context from both left and right of a word.
# 1. Excellent for understanding and interpreting text
# 2. Used for search, question answering, and NLP tasks
#
# Example: Google Search uses BERT to understand queries better.
