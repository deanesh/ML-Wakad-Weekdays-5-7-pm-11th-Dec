# %% [markdown]
# #### `Fine-Tuning / LoRA`
#
# Fine-tuning adapts a pre-trained generative AI model to a specific task or domain by further training it on task-specific data.
#
# LoRA (Low-Rank Adaptation) is a parameter-efficient fine-tuning method that updates only small low-rank matrices, saving memory and computation.
#
# Example: Fine-tuning GPT for legal document summarization using LoRA.
