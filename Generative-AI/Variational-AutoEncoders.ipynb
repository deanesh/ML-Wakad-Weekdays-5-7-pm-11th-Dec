# %% [markdown]
# #### `Variational Autoencoders (VAEs)`
#
# A VAE is a generative AI model that compresses data into a latent space and then reconstructs it, allowing smooth and controlled generation of new data.
#
# Learns probabilistic representations
#
# Can sample from latent space to create new, similar data
#
# Example: Generating new handwritten digits like MNIST.
