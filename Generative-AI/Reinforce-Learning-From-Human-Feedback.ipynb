# %% [markdown]
# #### `RLHF (Reinforcement Learning from Human Feedback)`
#
# RLHF is a technique to align AI model outputs with human preferences by:
#
# Training a model with human feedback on its responses
#
# Using reinforcement learning to reward preferred outputs
#
# Improves safety, usefulness, and relevance of AI-generated content
#
# Example: ChatGPT uses RLHF to give helpful and appropriate responses.
