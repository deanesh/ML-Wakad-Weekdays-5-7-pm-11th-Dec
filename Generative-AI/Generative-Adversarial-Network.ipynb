# %% [markdown]
# #### `GAN (Generative Adversarial Network)`
#
# A GAN is a generative AI model with two neural networks:
#
# `Generator`: creates fake data
#
# `Discriminator`: distinguishes real vs fake data
#
# Both compete, improving generation quality over time.
#
# Example: StyleGAN generates realistic human face images.
