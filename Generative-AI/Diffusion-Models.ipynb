# %% [markdown]
# #### `Diffusion Model`
#
# A Diffusion Model generates data by adding noise step-by-step to training data and learning to remove that noise, eventually creating high-quality new samples from pure noise.
#
# Produces very realistic outputs
#
# State-of-the-art for image and video generation
#
# Example: Stable Diffusion generates images from text prompts.
