# %% [markdown]
# #### LLM (Large Language Model)
#
# An LLM is a transformer-based generative AI model trained on massive text data to understand and generate human-like language by predicting the next token.
#
# Learns grammar, facts, and reasoning patterns
#
# Used for chatbots, summarization, translation, and code generation
#
# Example: ChatGPT is an LLM-based application.
