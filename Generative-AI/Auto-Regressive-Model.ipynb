# %% [markdown]
# #### `Autoregressive Model`
#
# An autoregressive model generates data one step at a time, using previous outputs as context to predict the next element.
#
# Common in text, music, and time-series generation
#
# Captures sequential dependencies effectively
#
# Example: GPT predicts the next word in a sentence based on previous words.
